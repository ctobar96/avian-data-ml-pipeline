# %%
# Importar librerias
import os
import pandas as pd
import glob

# %%
# Configurar pandas para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# 1. Ruta del archivo
ruta_Archivo = '../data/raw/AlimentoFabricado/ALIMENTOENERO2026.xls'

# 3. Leer cada archivo y concatenarlos en un solo DataFrame
df_Alimento = pd.read_excel(ruta_Archivo,)
lista_dataframes = []

for archivo in lista_archivos:
    try:
        df_temporal = pd.read_excel(archivo, sheet_name='Datos')
        lista_dataframes.append(df_temporal)
        print(f"Archivo leído correctamente: {archivo}")
    except Exception as e:
        print(f"Error al leer el archivo {archivo}: {e}")

# Concatenar todos los DataFrames en uno solo
df_raw_alimento = pd.concat(lista_dataframes, ignore_index=True)
print(f"DataFrame final creado con {len(df_raw_alimento)} filas.")

# 4. ver los resultados consolidados
print("--- Vista previa del DataFrame ---")
df_raw_alimento.info()

print("--- Primeras filas del DataFrame ---")
df_raw_alimento.head()
# Out:
# Buscando en: ../data/raw/AlimentoFabricado/*.xls
# Archivos encontrados: 0 archivos para procesar.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 26
#      23         print(f"Error al leer el archivo {archivo}: {e}")
#      25 # Concatenar todos los DataFrames en uno solo
# ---> 26 df_raw_alimento = pd.concat(lista_dataframes, ignore_index=True)
#      27 print(f"DataFrame final creado con {len(df_raw_alimento)} filas.")
#      29 # 4. ver los resultados consolidados
#
# File d:\crist\OneDrive\Estudios\Proyectos Para GitHub\avian-data-ml-pipeline\venv\Lib\site-packages\pandas\core\reshape\concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
# ...
